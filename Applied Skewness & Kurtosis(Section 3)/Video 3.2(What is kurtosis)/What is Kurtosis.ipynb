# %% [markdown]
# # What is Kurtosis?
# ## How thick is the tail, and sharp is the peak,compared to Normal Distribution!!
#
# ## Example::Higher Peaks have high kurtosis

# %% [markdown]
# ![kurt.gif](attachment:kurt.gif)

# %% [markdown]
# ![kurt1.PNG](attachment:kurt1.PNG)

# %% [markdown]
# # Different Types of Kurtosis
#
# ![kurt2.jpg](attachment:kurt2.jpg)

# %% [markdown]
# ## Meskurtis is nearly equivalent to Normal Distribution
